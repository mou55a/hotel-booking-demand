# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

sns.set()

# %%
raw_data = pd.read_csv('hotel_booking.csv')
raw_data.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  customer_type  \
# 0                        0                     0       2  ...      Transient
# ...

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 36 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
raw_data.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
raw_data.describe(include ='all').T
# Out:
#                                  count  unique                  top    freq  \
# hotel                           119390       2           City Hotel   79330
# is_canceled                     119390     NaN                  NaN     NaN
# lead_time                       119390     NaN                  NaN     NaN
# arrival_date_year               119390     NaN                  NaN     NaN
# arrival_date_month              119390      12               August   13877
# arrival_date_week_number        119390     NaN                  NaN     NaN
# arrival_date_day_of_month       119390     NaN                  NaN     NaN
# stays_in_weekend_nights         119390     NaN                  NaN     NaN
# stays_in_week_nights            119390     NaN                  NaN     NaN
# adults                          119390     NaN                  NaN     NaN
# children                        119386     NaN                  NaN     NaN
# ...

# %%
raw_data.duplicated().sum()
# Out:
# 0

# %%
raw_data.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  customer_type  \
# 0                        0                     0       2  ...      Transient
# ...

# %%
raw_data.company.value_counts()
# Out:
# 40.0     927
# 223.0    784
# 67.0     267
# 45.0     250
# 153.0    215
#         ...
# 229.0      1
# 213.0      1
# 416.0      1
# 320.0      1
# 461.0      1
# Name: company, Length: 352, dtype: int64

# %%
raw_data.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date', 'name', 'email',
#        'phone-number', 'credit_card'],
#       dtype='object')

# %%
droped_col = ['agent','company', 'name', 'email','phone-number', 'credit_card']
data_after_drop = raw_data.drop(columns = droped_col)  

data_after_drop.isna().sum()
# Out:
# hotel                               0
# is_canceled                         0
# lead_time                           0
# arrival_date_year                   0
# arrival_date_month                  0
# arrival_date_week_number            0
# arrival_date_day_of_month           0
# stays_in_weekend_nights             0
# stays_in_week_nights                0
# adults                              0
# children                            4
# babies                              0
# meal                                0
# country                           488
# market_segment                      0
# distribution_channel                0
# is_repeated_guest                   0
# previous_cancellations              0
# previous_bookings_not_canceled      0
# reserved_room_type                  0
# assigned_room_type                  0
# booking_changes                     0
# deposit_type                        0
# days_in_waiting_list                0
# customer_type                       0
# ...

# %%
data_after_drop[data_after_drop['country'].isna() ==True ].is_canceled.value_counts()
# Out:
# 0    421
# 1     67
# Name: is_canceled, dtype: int64

# %%
data_after_drop['children'] = data_after_drop['children'].map({0:0,1:1,2:2,3:3,10:3})
data_after_drop['babies'] = data_after_drop['babies'].map({0:0,1:1,2:2,9:2,10:2})
data_after_drop['children'] = data_after_drop['children'].fillna(value = 0)
data_no_mv = data_after_drop.dropna().reset_index()

# %%
data_no_mv.isna().sum()
# Out:
# index                             0
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# days_in_waiting_list              0
# customer_type                     0
# ...

# %%
data_no_mv.describe(include = 'all').T
# Out:
#                                  count unique         top    freq        mean  \
# index                           118902    NaN         NaN     NaN     59872.1
# hotel                           118902      2  City Hotel   79306         NaN
# is_canceled                     118902    NaN         NaN     NaN    0.371373
# lead_time                       118902    NaN         NaN     NaN     104.308
# arrival_date_year               118902    NaN         NaN     NaN     2016.16
# arrival_date_month              118902     12      August   13856         NaN
# arrival_date_week_number        118902    NaN         NaN     NaN     27.1667
# arrival_date_day_of_month       118902    NaN         NaN     NaN     15.8006
# stays_in_weekend_nights         118902    NaN         NaN     NaN    0.928891
# stays_in_week_nights            118902    NaN         NaN     NaN     2.50214
# adults                          118902    NaN         NaN     NaN      1.8584
# ...

# %%
print('hotel values:\n',data_no_mv.hotel.value_counts())
print('\narrival_date_month values:\n',data_no_mv.arrival_date_month.value_counts())
print('\nmeal values:\n',data_no_mv.meal.value_counts())
print('\nmarket_segment values:\n',data_no_mv.market_segment.value_counts())
print('\ndistribution_channel values:\n',data_no_mv.distribution_channel.value_counts())
print('\nreserved_room_type values:\n',data_no_mv.reserved_room_type.value_counts())
print('\nassigned_room_type values:\n',data_no_mv.assigned_room_type.value_counts())
print('\ndeposit_type values:\n',data_no_mv.deposit_type.value_counts())
print('\ncustomer_type values:\n',data_no_mv.customer_type.value_counts())
print('\nreservation_status values:\n',data_no_mv.reservation_status.value_counts())
# Out:
# hotel values:
#  City Hotel      79306
# Resort Hotel    39596
# Name: hotel, dtype: int64
#
# arrival_date_month values:
#  August       13856
# July         12628
# May          11779
# October      11095
# April        11045
# June         10927
# September    10467
# March         9739
# February      8012
# November      6752
# December      6728
# January       5874
# Name: arrival_date_month, dtype: int64
#
# meal values:
#  BB           91867
# HB           14434
# SC           10638
# Undefined     1165
# FB             798
# Name: meal, dtype: int64
#
# market_segment values:
#  Online TA        56403
# Offline TA/TO    24160
# Groups           19806
# Direct           12449
# Corporate         5111
# Complementary      734
# Aviation           237
# Undefined            2
# Name: market_segment, dtype: int64
#
# distribution_channel values:
#  TA/TO        97730
# Direct       14483
# Corporate     6491
# GDS            193
# Undefined        5
# ...

# %%
country = list(set(data_no_mv.country.values))
country
# Out:
# ['BFA',
#  'IDN',
#  'KEN',
#  'MUS',
#  'HUN',
#  'KAZ',
#  'BEN',
#  'BEL',
#  'PRI',
#  'TWN',
#  'SLV',
#  'SLE',
#  'KOR',
#  'SVN',
#  'MAR',
#  'UKR',
#  'GGY',
#  'NGA',
#  'UMI',
#  'MRT',
#  'CMR',
#  'ZWE',
#  'IRQ',
#  'ARG',
#  'NIC',
#  'ITA',
#  'DJI',
#  'NAM',
#  'DNK',
#  'SYR',
#  'GNB',
#  'AGO',
#  'SVK',
#  'VEN',
#  'SWE',
#  'TUR',
#  'DZA',
#  'VGB',
#  'MDG',
#  'CYP',
#  'MMR',
#  'KHM',
#  'RUS',
#  'SMR',
#  'ISL',
#  'CHN',
#  'NPL',
#  'CPV',
#  'ETH',
#  'EST',
#  'JOR',
#  'NCL',
#  'POL',
#  'UGA',
#  'MYT',
#  'ASM',
#  'DEU',
#  'LTU',
#  'ARE',
#  'SEN',
#  'AUT',
#  'MWI',
#  'COM',
#  'BLR',
#  'PHL',
#  'ATA',
#  'JAM',
#  'HKG',
#  'PRT',
#  'PYF',
#  'GUY',
#  'CAF',
#  'ZMB',
#  'CYM',
#  'BHS',
#  'PLW',
#  'CIV',
#  'ABW',
#  'ALB',
#  'ECU',
#  'ARM',
#  'ZAF',
#  'MCO',
#  'TJK',
#  'PAK',
#  'MKD',
#  'NLD',
#  'JPN',
#  'BRB',
#  'NZL',
#  'AND',
#  'MLI',
#  'CHL',
#  'LBN',
#  'THA',
#  'GHA',
#  'EGY',
#  'OMN',
#  'BOL',
#  'LVA',
# ...

# %%
country_code = pd.read_csv('country_table.csv')
country_code
# Out:
#                Country Alpha-2 code Alpha-3 code  Numeric code  \
# 0          Afghanistan           AF          AFG             4
# 1              Albania           AL          ALB             8
# 2              Algeria           DZ          DZA            12
# 3       American Samoa           AS          ASM            16
# 4              Andorra           AD          AND            20
# ..                 ...          ...          ...           ...
# 251  Wallis and Futuna           WF          WLF           876
# 252     Western Sahara           EH          ESH           732
# 253              Yemen           YE          YEM           887
# 254             Zambia           ZM          ZMB           894
# 255           Zimbabwe           ZW          ZWE           716
#
#      Latitude (average)  Longitude (average)
# 0               33.0000                 65.0
# 1               41.0000                 20.0
# 2               28.0000                  3.0
# ...

# %%
lon = {d['Alpha-3 code']: d['Longitude (average)'] for d in country_code.to_dict(orient='records')}

lat = {d['Alpha-3 code']: d['Latitude (average)'] for d in country_code.to_dict(orient='records')}

# %%
data_no_mv['Latitude'] = data_no_mv['country'].map(lat)

data_no_mv['Longitude'] = data_no_mv['country'].map(lon)

# %%
data_no_mv.columns.values
# Out:
# array(['index', 'hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type',
#        'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date', 'Latitude',
#        'Longitude'], dtype=object)

# %%
col =['hotel', 'lead_time', 'arrival_date_year','arrival_date_month', 'arrival_date_week_number','arrival_date_day_of_month', 'stays_in_weekend_nights',
'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
'market_segment', 'distribution_channel',
'is_repeated_guest', 'previous_cancellations',
'previous_bookings_not_canceled', 'reserved_room_type',
'assigned_room_type', 'booking_changes', 'deposit_type',
'days_in_waiting_list', 'customer_type', 'adr',
'required_car_parking_spaces', 'total_of_special_requests',
'reservation_status', 'reservation_status_date', 'Latitude',
'Longitude','is_canceled']
data_with_geo = data_no_mv[col]
data_with_geo.describe(include = 'all').T
# Out:
#                                  count unique         top    freq        mean  \
# hotel                           118902      2  City Hotel   79306         NaN
# lead_time                       118902    NaN         NaN     NaN     104.308
# arrival_date_year               118902    NaN         NaN     NaN     2016.16
# arrival_date_month              118902     12      August   13856         NaN
# arrival_date_week_number        118902    NaN         NaN     NaN     27.1667
# arrival_date_day_of_month       118902    NaN         NaN     NaN     15.8006
# stays_in_weekend_nights         118902    NaN         NaN     NaN    0.928891
# stays_in_week_nights            118902    NaN         NaN     NaN     2.50214
# adults                          118902    NaN         NaN     NaN      1.8584
# children                        118902    NaN         NaN     NaN    0.104145
# babies                          118902    NaN         NaN     NaN  0.00782157
# ...

# %%
data_with_geo['meal'].unique()
# Out:
# array(['BB', 'FB', 'HB', 'SC', 'Undefined'], dtype=object)

# %%
data_with_geo['hotel']= data_with_geo['hotel'].map({'Resort Hotel':0,'City Hotel':1})
data_with_geo['arrival_date_month']=data_with_geo['arrival_date_month'].map({'January':1,'February':2,'March':3,'April':4,'May':5,'June':6,'July':7,'August':8,'September':9, 'October':10,'November':11, 'December':12})

data_with_geo
# Out:
# <ipython-input-23-ef02d8caee70>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_with_geo['hotel']= data_with_geo['hotel'].map({'Resort Hotel':0,'City Hotel':1})
# <ipython-input-23-ef02d8caee70>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_with_geo['arrival_date_month']=data_with_geo['arrival_date_month'].map({'January':1,'February':2,'March':3,'April':4,'May':5,'June':6,'July':7,'August':8,'September':9, 'October':10,'November':11, 'December':12})
# ...

# %%
cols =['hotel', 'lead_time','arrival_date_month','arrival_date_day_of_month', 'stays_in_weekend_nights',
'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
'market_segment', 'distribution_channel',
'is_repeated_guest', 'previous_cancellations',
'previous_bookings_not_canceled', 'reserved_room_type',
'assigned_room_type', 'booking_changes', 'deposit_type',
'days_in_waiting_list', 'customer_type', 'adr',
'required_car_parking_spaces', 'total_of_special_requests',
'reservation_status', 'Latitude',
'Longitude','is_canceled']

data_clean = data_with_geo[cols]
data_clean.shape
# Out:
# (118902, 28)

# %%
data_clean.is_canceled.sum()/118902
# Out:
# 0.3713730635313115

# %%
data_with_dummies = pd.get_dummies(data_clean, drop_first=True)
data_with_dummies.columns.values
# Out:
# array(['hotel', 'lead_time', 'arrival_date_month',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'booking_changes',
#        'days_in_waiting_list', 'adr', 'required_car_parking_spaces',
#        'total_of_special_requests', 'Latitude', 'Longitude',
#        'is_canceled', 'meal_FB', 'meal_HB', 'meal_SC', 'meal_Undefined',
#        'market_segment_Complementary', 'market_segment_Corporate',
#        'market_segment_Direct', 'market_segment_Groups',
#        'market_segment_Offline TA/TO', 'market_segment_Online TA',
#        'market_segment_Undefined', 'distribution_channel_Direct',
#        'distribution_channel_GDS', 'distribution_channel_TA/TO',
#        'distribution_channel_Undefined', 'reserved_room_type_B',
#        'reserved_room_type_C', 'reserved_room_type_D',
# ...

# %%
data_with_dummies.shape
# Out:
# (118902, 62)

# %%
columns_arr = ['hotel', 'lead_time', 'arrival_date_month',
       'arrival_date_day_of_month', 'stays_in_weekend_nights',
       'stays_in_week_nights', 'adults', 'children', 'babies',
       'is_repeated_guest', 'previous_cancellations',
       'previous_bookings_not_canceled', 'booking_changes',
       'days_in_waiting_list', 'adr', 'required_car_parking_spaces',
       'total_of_special_requests',
        'meal_FB', 'meal_HB', 'meal_SC', 'meal_Undefined',
       'market_segment_Complementary', 'market_segment_Corporate',
       'market_segment_Direct', 'market_segment_Groups',
       'market_segment_Offline TA/TO', 'market_segment_Online TA',
       'market_segment_Undefined', 'distribution_channel_Direct',
       'distribution_channel_GDS', 'distribution_channel_TA/TO',
       'distribution_channel_Undefined', 'reserved_room_type_B',
       'reserved_room_type_C', 'reserved_room_type_D',
       'reserved_room_type_E', 'reserved_room_type_F',
       'reserved_room_type_G', 'reserved_room_type_H',
       'reserved_room_type_L', 'reserved_room_type_P',
       'assigned_room_type_B', 'assigned_room_type_C',
       'assigned_room_type_D', 'assigned_room_type_E',
       'assigned_room_type_F', 'assigned_room_type_G',
       'assigned_room_type_H', 'assigned_room_type_I',
       'assigned_room_type_K', 'assigned_room_type_L',
       'assigned_room_type_P', 'deposit_type_Non Refund',
       'deposit_type_Refundable', 'customer_type_Group',
       'customer_type_Transient', 'customer_type_Transient-Party',
       'reservation_status_Check-Out', 'reservation_status_No-Show','is_canceled']
data_rearranged = data_with_dummies[columns_arr]

# %%
targets = data_rearranged['is_canceled']
unscaled_inputs = data_rearranged.iloc[:,:-1]

# %%
targets.describe(include='all').T
# Out:
# count    118902.000000
# mean          0.371373
# std           0.483174
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           1.000000
# max           1.000000
# Name: is_canceled, dtype: float64

# %%
unscaled_inputs.describe(include='all').T
# Out:
#                                    count        mean         std   min   25%  \
# hotel                           118902.0    0.666986    0.471293  0.00   0.0
# lead_time                       118902.0  104.308027  106.903127  0.00  18.0
# arrival_date_month              118902.0    6.552934    3.087010  1.00   4.0
# arrival_date_day_of_month       118902.0   15.800567    8.780371  1.00   8.0
# stays_in_weekend_nights         118902.0    0.928891    0.996211  0.00   0.0
# stays_in_week_nights            118902.0    2.502136    1.900165  0.00   1.0
# adults                          118902.0    1.858404    0.578576  0.00   2.0
# children                        118902.0    0.104145    0.398222  0.00   0.0
# babies                          118902.0    0.007822    0.089608  0.00   0.0
# is_repeated_guest               118902.0    0.032010    0.176026  0.00   0.0
# previous_cancellations          118902.0    0.087139    0.845855  0.00   0.0
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
scaler.fit(unscaled_inputs)
# Out:
# StandardScaler()

# %%
scaled_inputs = scaler.transform(unscaled_inputs)

# %%
scaled_inputs
# Out:
# array([[-1.4152311 ,  2.22344265,  0.1448222 , ..., -0.51705098,
#          0.76861474, -0.1010989 ],
#        [-1.4152311 ,  5.91839219,  0.1448222 , ..., -0.51705098,
#          0.76861474, -0.1010989 ],
#        [-1.4152311 , -0.91024873,  0.1448222 , ..., -0.51705098,
#          0.76861474, -0.1010989 ],
#        ...,
#        [ 0.70659838, -0.65768256,  0.46876166, ..., -0.51705098,
#          0.76861474, -0.1010989 ],
#        [ 0.70659838,  0.04389014,  0.46876166, ..., -0.51705098,
#          0.76861474, -0.1010989 ],
#        [ 0.70659838,  0.94190319,  0.46876166, ..., -0.51705098,
#          0.76861474, -0.1010989 ]])

# %%
scaled_inputs.shape
# Out:
# (118902, 59)

# %%
from sklearn.model_selection import train_test_split

# %%
# check how this method works
train_test_split(scaled_inputs, targets)
# Out:
# [array([[ 0.70659838, -0.4331793 , -0.17911725, ..., -0.51705098,
#           0.76861474, -0.1010989 ],
#         [ 0.70659838, -0.97572885,  0.79270111, ...,  1.93404526,
#           0.76861474, -0.1010989 ],
#         [-1.4152311 , -0.97572885,  1.76451947, ..., -0.51705098,
#           0.76861474, -0.1010989 ],
#         ...,
#         [-1.4152311 ,  0.48354236, -0.50305671, ...,  1.93404526,
#           0.76861474, -0.1010989 ],
#         [ 0.70659838,  0.80158865, -0.82699616, ...,  1.93404526,
#           0.76861474, -0.1010989 ],
#         [ 0.70659838, -0.97572885, -0.50305671, ..., -0.51705098,
#           0.76861474, -0.1010989 ]]),
#  array([[-1.4152311 , -0.92895734,  1.44058002, ..., -0.51705098,
#           0.76861474, -0.1010989 ],
#         [-1.4152311 , -0.68574547,  1.44058002, ...,  1.93404526,
#           0.76861474, -0.1010989 ],
#         [-1.4152311 ,  0.10001595,  0.46876166, ..., -0.51705098,
#           0.76861474, -0.1010989 ],
#         ...,
# ...

# %%
# declare 4 variables for the split
x_train, x_test, y_train, y_test = train_test_split(scaled_inputs, targets, test_size = 0.2, random_state = 20)

# %%
# check the shape of the train inputs and targets
print (x_train.shape, y_train.shape)
# Out:
# (95121, 59) (95121,)

# %%
# check the shape of the test inputs and targets
print (x_test.shape, y_test.shape)
# Out:
# (23781, 59) (23781,)

# %%
# import the LogReg model from sklearn
from sklearn.linear_model import LogisticRegression

# import the 'metrics' module, which includes important metrics we may want to use
from sklearn import metrics

# %%
# create a logistic regression object
reg = LogisticRegression()

# %%
# fit our train inputs
# that is basically the whole training part of the machine learning
reg.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
# assess the train accuracy of the model
reg.score(x_train,y_train)
# Out:
# 1.0

# %%
# assess the train accuracy of the model
reg.score(x_train,y_train)
# Out:
# 1.0

# %%
model_outputs = reg.predict(x_train)
model_outputs
# Out:
# array([0, 0, 1, ..., 0, 0, 0], dtype=int64)

# %%
model_outputs.shape[0]
# Out:
# 95121

# %%
np.sum((model_outputs==y_train)) / model_outputs.shape[0]
# Out:
# 1.0

# %%
reg.intercept_
# Out:
# array([-2.58711257])

# %%
reg.coef_
# Out:
# array([[ 2.98264137e-03,  2.08955148e-01,  1.43349679e-02,
#          8.13413723e-04,  8.70752232e-03,  3.45907681e-02,
#          4.58974135e-02,  3.30206760e-02,  6.31032776e-03,
#         -4.64988680e-02,  2.18090571e-01, -5.43064178e-02,
#         -1.00101110e-01, -3.78670512e-03,  9.31994142e-02,
#         -3.72673792e-01, -2.38750117e-01,  2.11848093e-02,
#         -2.18210455e-02, -3.86079731e-03, -2.12138087e-02,
#          1.07574914e-02, -1.40622987e-02, -4.53923149e-02,
#          5.45830415e-02, -1.18890999e-01,  9.00309317e-02,
#          8.11223759e-03, -4.32219731e-02, -1.10878817e-02,
#          3.55276036e-02,  8.98194366e-03,  2.86711706e-02,
#          3.82154374e-02,  9.37340933e-02,  6.98117938e-02,
#          3.69083622e-02,  4.49134358e-02,  1.71306453e-02,
#          1.97820898e-03,  5.86404127e-03, -4.15938300e-02,
#         -6.71010989e-02, -1.65424028e-01, -9.92778419e-02,
#         -8.62644479e-02, -7.21230752e-02, -2.44189729e-02,
# ...

# %%
unscaled_inputs.columns.values
# Out:
# array(['hotel', 'lead_time', 'arrival_date_month',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'booking_changes',
#        'days_in_waiting_list', 'adr', 'required_car_parking_spaces',
#        'total_of_special_requests', 'meal_FB', 'meal_HB', 'meal_SC',
#        'meal_Undefined', 'market_segment_Complementary',
#        'market_segment_Corporate', 'market_segment_Direct',
#        'market_segment_Groups', 'market_segment_Offline TA/TO',
#        'market_segment_Online TA', 'market_segment_Undefined',
#        'distribution_channel_Direct', 'distribution_channel_GDS',
#        'distribution_channel_TA/TO', 'distribution_channel_Undefined',
#        'reserved_room_type_B', 'reserved_room_type_C',
#        'reserved_room_type_D', 'reserved_room_type_E',
# ...

# %%
feature_name = unscaled_inputs.columns.values

# %%
summary_table = pd.DataFrame (columns=['Feature name'], data = feature_name)

# add the coefficient values to the summary table
summary_table['Coefficient'] = np.transpose(reg.coef_)

# display the summary table
summary_table
# Out:
#                       Feature name  Coefficient
# 0                            hotel     0.002983
# 1                        lead_time     0.208955
# 2               arrival_date_month     0.014335
# 3        arrival_date_day_of_month     0.000813
# 4          stays_in_weekend_nights     0.008708
# 5             stays_in_week_nights     0.034591
# 6                           adults     0.045897
# 7                         children     0.033021
# 8                           babies     0.006310
# 9                is_repeated_guest    -0.046499
# 10          previous_cancellations     0.218091
# 11  previous_bookings_not_canceled    -0.054306
# 12                 booking_changes    -0.100101
# 13            days_in_waiting_list    -0.003787
# 14                             adr     0.093199
# 15     required_car_parking_spaces    -0.372674
# 16       total_of_special_requests    -0.238750
# 17                         meal_FB     0.021185
# 18                         meal_HB    -0.021821
# ...

# %%
summary_table.index = summary_table.index + 1

# add the intercept at index 0
summary_table.loc[0] = ['Intercept', reg.intercept_[0]]

# sort the df by index
summary_table = summary_table.sort_index()
summary_table
# Out:
#                       Feature name  Coefficient
# 0                        Intercept    -2.587113
# 1                            hotel     0.002983
# 2                        lead_time     0.208955
# 3               arrival_date_month     0.014335
# 4        arrival_date_day_of_month     0.000813
# 5          stays_in_weekend_nights     0.008708
# 6             stays_in_week_nights     0.034591
# 7                           adults     0.045897
# 8                         children     0.033021
# 9                           babies     0.006310
# 10               is_repeated_guest    -0.046499
# 11          previous_cancellations     0.218091
# 12  previous_bookings_not_canceled    -0.054306
# 13                 booking_changes    -0.100101
# 14            days_in_waiting_list    -0.003787
# 15                             adr     0.093199
# 16     required_car_parking_spaces    -0.372674
# 17       total_of_special_requests    -0.238750
# 18                         meal_FB     0.021185
# ...

# %%
summary_table['Odds_ratio'] = np.exp(summary_table.Coefficient)

# %%
summary_table
# Out:
#                       Feature name  Coefficient  Odds_ratio
# 0                        Intercept    -2.587113    0.075237
# 1                            hotel     0.002983    1.002987
# 2                        lead_time     0.208955    1.232390
# 3               arrival_date_month     0.014335    1.014438
# 4        arrival_date_day_of_month     0.000813    1.000814
# 5          stays_in_weekend_nights     0.008708    1.008746
# 6             stays_in_week_nights     0.034591    1.035196
# 7                           adults     0.045897    1.046967
# 8                         children     0.033021    1.033572
# 9                           babies     0.006310    1.006330
# 10               is_repeated_guest    -0.046499    0.954566
# 11          previous_cancellations     0.218091    1.243700
# 12  previous_bookings_not_canceled    -0.054306    0.947142
# 13                 booking_changes    -0.100101    0.904746
# 14            days_in_waiting_list    -0.003787    0.996220
# ...

# %%
summary_table.sort_values('Odds_ratio', ascending=False)
# Out:
#                       Feature name  Coefficient  Odds_ratio
# 53         deposit_type_Non Refund     0.602022    1.825807
# 59      reservation_status_No-Show     0.234044    1.263700
# 11          previous_cancellations     0.218091    1.243700
# 2                        lead_time     0.208955    1.232390
# 56         customer_type_Transient     0.102557    1.108001
# 35            reserved_room_type_D     0.093734    1.098268
# 15                             adr     0.093199    1.097681
# 27        market_segment_Online TA     0.090031    1.094208
# 36            reserved_room_type_E     0.069812    1.072306
# 25           market_segment_Groups     0.054583    1.056100
# 7                           adults     0.045897    1.046967
# 38            reserved_room_type_G     0.044913    1.045937
# 34            reserved_room_type_C     0.038215    1.038955
# 37            reserved_room_type_F     0.036908    1.037598
# 31      distribution_channel_TA/TO     0.035528    1.036166
# ...

# %%
predicted_proba = reg.predict_proba(x_train)
predicted_proba
# Out:
# array([[9.99914973e-01, 8.50271911e-05],
#        [9.99962176e-01, 3.78243952e-05],
#        [2.13715288e-04, 9.99786285e-01],
#        ...,
#        [9.99995039e-01, 4.96086702e-06],
#        [9.99962455e-01, 3.75449604e-05],
#        [9.99840010e-01, 1.59990342e-04]])

# %%
predicted_proba.shape
# Out:
# (95121, 2)

# %%
predicted_proba[:,1]
# Out:
# array([8.50271911e-05, 3.78243952e-05, 9.99786285e-01, ...,
#        4.96086702e-06, 3.75449604e-05, 1.59990342e-04])
